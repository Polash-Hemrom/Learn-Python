# %% [markdown]
# ### Variable Assignment

# %%
x = 2
name = 'Alice'
items =[2, 4, 6, 8]

print(x)
print(name)
print(items)
# Out:
# 2
# Alice
# [2, 4, 6, 8]

# %% [markdown]
# ### Multiple Assignment

# %%
x = y = z = None

# %%
a = b = c = []
a.append(2)

print(a)
print(b)
print(c)

## Parallel Assignment

a, b, c = 2, 4, 6
print(a)
print(b)
print(c)
# Out:
# [2]
# [2]
# [2]
# 2
# 4
# 6

# %% [markdown]
# ### Unpacking

# %%
data = ['Apple', 2, 4.2]
x, y, z = data
print(data)
# Out:
# ['Apple', 2, 4.2]

# %%
## Return value Unpacking
def get_values ():
    return (2, 4, 6)

a, b, c = get_values()
print(a)
print(b)
print(c)
# Out:
# 2
# 4
# 6

# %%
## *Asterisk unpacking

first, *rest = [2, 4, 6, 8, 10]
print(first)
print(rest)
# Out:
# 2
# [4, 6, 8, 10]

# %%
# Mismattched Count

a, *b = [2, 4, 6, 8, 10]    # ValueError
a, *b, c = [2, 4]           # ValueError

print(a)
print(b)
print(a)
print(c)
# Out:
# 2
# []
# 2
# 4

# %% [markdown]
# ### type() and isinstance()

# %%
type(2)         # <class 'int'>
type(4.2)       # <class 'float'>
type('hi')      # <class 'str'>
type([2, 4])    # <class 'list'>
# Out:
# list

# %% [markdown]
# ### Returning types from unpacked data

# %%
data = ['apple', 2, 4.4]
a, b, c  = data
result = (type(a), type(b), type(c))
print(result)
# Out:
# (<class 'str'>, <class 'int'>, <class 'float'>)

# %% [markdown]
# ### isinstance()

# %%
# isinstance(obj, type)

isinstance(2, int)      #True
isinstance(4.2, float)  #True
isinstance('hi', str)   #True
isinstance(2,(int, float))  #True
# Out:
# True

# %%
# Subclass Handling

class child(list):
    pass

c = child()
type(c) == list
isinstance(c, list)
# Out:
# True

# %% [markdown]
# ### Global Variables and the global keyword

# %%
x = 2

def set_local():
    x = 4   # Local x: global x unchanged
    print(x)

set_local()
print(x)
# Out:
# 4
# 2

# %%
# The global keyword: Use global name to assign to a global variable from inside a function. Without it, assignment creates a local.

x = y = z =None
data = ['Apple', 2, 4.2]

def assign_globals():
    global x, y, z

assign_globals()
print(assign_globals)
# Out:
# <function assign_globals at 0x7273406c5bc0>

# %%
# Read vs write: Reading a global does not require global. Only assignment does.

count = 0

def read_global():
    print(count)

def write_global():
    global count
    count += 2

# %%
import math

# s to store string
# n to store integer
# f to store float
# ff  # To Store floor of float variable f

# code here
s = input()
n = int(input())
ff = float(input())


print(s)
print(n)
print(ff)
# Out:
# 'Hello'
# 15
# 5.5

# %%
a = ('Hello')
b = ('World')
separator = ('@')

# code here
print(f'{a}"{separator}"{b} ')
# Out:
# Hello"@"World

# %%
# code here
class solution:
    def last_digit (self, n):
        return n % 10
    
solution = fo(n(120))
print(my_class)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       2 class solution:
#       3     def last_digit (self, n):
#       4         return n % 10
#       5
# ----> 6 my_class = n(solution(120))
#       7 print(my_class)
#
# TypeError: solution() takes no arguments

# %%
p = int(input())
r = int(input())
t = int(input())

# code here
simple_interest = (p * r * t) /100
print (float(simple_interest))
# Out:
# 40.0
